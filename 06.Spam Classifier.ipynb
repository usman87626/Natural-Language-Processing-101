# %% [markdown]
# ## Reading Dataset

# %%
import pandas as pd

# %%
message_df = pd.read_csv("dataset/SMSSpamCollection",sep='\t',names=["label","message"])

# %%
message_df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## Data cleaning & pre-processing

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer,WordNetLemmatizer

# %%
ps = PorterStemmer()
corpus = []
nltk.sent_tokenize
for idx in range(len(message_df)):
    review = re.sub("^[A-Za-z]"," ",message_df['message'][idx])
    review = review.lower()
    review = review.strip()
    
    review = [ps.stem(word) for word in nltk.word_tokenize(review) if not word in stopwords.words("english")]
    
    review = " ".join(review)
    corpus.append(review)

# %%
print(corpus)
# Out:
# ['jurong point , crazi .. avail bugi n great world la e buffet ... cine got amor wat ...', 'k lar ... joke wif u oni ...', "ree entri 2 wkli comp win fa cup final tkt 21st may 2005. text fa 87121 receiv entri question ( std txt rate ) & c 's appli 08452810075over18 's", 'dun say earli hor ... u c alreadi say ...', "ah n't think goe usf , live around though", "reemsg hey darl 's 3 week 's word back ! 'd like fun still ? tb ok ! xxx std chg send , £1.50 rcv", 'ven brother like speak . treat like aid patent .', "per request 'mell mell ( oru minnaminungint nurungu vettam ) ' set callertun caller . press * 9 copi friend callertun", 'inner ! ! valu network custom select receivea £900 prize reward ! claim call 09061701461. claim code kl341 . valid 12 hour .', 'ad mobil 11 month ? u r entitl updat latest colour mobil camera free ! call mobil updat co free 08002986030', "'m gon na home soon n't want talk stuff anymor tonight , k ? 've cri enough today .", 'ix chanc win cash ! 100 20,000 pound txt > csh11 send 87575. cost 150p/day , 6day , 16+ tsandc appli repli hl 4 info', 'rgent ! 1 week free membership £100,000 prize jackpot ! txt word : claim : 81010 & c www.dbuk.net lccltd pobox 4403ldnw1a7rw18', "'ve search right word thank breather . promis wont take help grant fulfil promis . wonder bless time .", 'date sunday ! !', 'xxmobilemovieclub : use credit , click wap link next txt messag click > > http : //wap . xxxmobilemovieclub.com ? n=qjkgighjjgcbl', "h k ... 'm watch : )", 'h u rememb 2 spell name ... ye . v naughti make v wet .', 'ine that\x92 way u feel . that\x92 way gota b', 'ngland v macedonia - dont miss goals/team news . txt ur nation team 87077 eg england 87077 tri : wale , scotland 4txt/ú1.20 poboxox36504w45wq 16+', 'serious spell name ?', '‘ go tri 2 month ha ha joke', 'ü pay first lar ... da stock comin ...', 'ft finish lunch go str lor . ard 3 smth lor . u finish ur lunch alreadi ?', 'fffffffff . alright way meet sooner ?', "ust forc eat slice . 'm realli hungri tho . suck . mark get worri . know 'm sick turn pizza . lol", 'ol alway convinc .', "id catch bu ? fri egg ? make tea ? eat mom 's left dinner ? feel love ?", "'m back & amp ; 're pack car , 'll let know 's room", 'hhh . work . vagu rememb ! feel like ? lol', "ait 's still clear , sure sarcast 's x n't want live us", "eah got 2 v apologet . n fallen actin like spoilt child got caught . till 2 ! wo n't go ! badli cheer . ?", 'tell anyth .', 'fear faint housework ? quick cuppa', 'hank subscript rington uk mobil charg £5/month pleas confirm repli ye . repli charg', '... ok go home look time msg ü ... xuhui go learn 2nd may lesson 8am', "op , 'll let know roommat 's done", 'see letter b car', 'nyth lor ... u decid ...', "ello ! 's saturday go ? text see 'd decid anyth tomo . 'm tri invit anyth !", 'ls go ahead watt . want sure . great weekend . abiola', 'id forget tell ? want , need , crave ... ... love sweet arabian steed ... mmmmmm ... yummi', '07732584351 - rodger burn - msg = tri call repli sm free nokia mobil + free camcord . pleas call 08000930705 deliveri tomorrow', 'ho see ?', 'reat ! hope like man well endow . & lt ; # & gt ; inch ...', 'call .. messag .. miss call', "id n't get hep b immunis nigeria .", 'air enough , anyth go ?', "eah hope , tyler ca n't could mayb ask around bit", "n't know stubborn . n't even want go hospit . kept tell mark 'm weak sucker . hospit weak sucker .", 'hat think . first time saw class .', 'gram usual run like & lt ; # & gt ; , half eighth smarter though get almost whole second gram & lt ; # & gt ;', "fyi x ride earli tomorrow morn 's crash place tonight", "ow . never realiz embarass accomod . thought like , sinc best could alway seem happi `` cave '' . 'm sorri n't n't give . 'm sorri offer . 'm sorri room embarass .", 'ms. ac sptv : new jersey devil detroit red wing play ice hockey . correct incorrect ? end ? repli end sptv', 'know mallika sherawat yesterday ? find @ & lt ; url & gt ;', 'ongrat ! 1 year special cinema pass 2 ...

# %% [markdown]
# ## Bag Of Words

# %%
## CREATING BAG OF WORDS
from sklearn.feature_extraction.text import CountVectorizer

## SELECT ONLY 5000 most frequent words
cv = CountVectorizer(max_features=5000)
X = cv.fit_transform(corpus).toarray()

# %%
y = pd.get_dummies(message_df['label'])
y = y.iloc[:,1].values

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Training the model

# %%
# Training model using Naive bayes classifier
from sklearn.naive_bayes import MultinomialNB

spam_detect_model = MultinomialNB()
spam_detect_model.fit(X_train,y_train)

y_pred = spam_detect_model.predict(X_test)

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

confusion_m = confusion_matrix(y_test,y_pred)
accuracy = accuracy_score(y_test,y_pred)

# %%
confusion_m
# Out:
# array([[944,  11],
#        [  6, 154]], dtype=int64)

# %%
accuracy
# Out:
# 0.9847533632286996
